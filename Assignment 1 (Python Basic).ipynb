# %% [markdown]
# # Python Practice Problems

# %% [markdown]
# ### 1. Find the Largest of Two Numbers
# **Task:** Given two numbers, find the larger one.
# **Demo Input:**  5 and 6 <br>
# **Output:** 6

# %%
first = float(input("Give first number: "))
second = float(input("Give second number: "))

if first > second:
    largest = first
elif second > first:
    largest = second
else:
    largest = first  # or second, since they are equal
    print("Both numbers are equal:", first)

print(f"The two numbers are {first} and {second}, and the largest one is {largest}")
# Out:
# The two numbers are 5.0 and 6.0, and the largest one is 6.0

# %% [markdown]
# ### 2. Print Numbers from 1 to N
# **Task**: Given a number `n`, print all numbers from 1 to `n`. <br>
# **Demo Input**: `5`  <br>
# **Demo Output**:  1 2 3 4 5

# %%
n = int(input("Give the Value of n : "))

for i in range(1,n+1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### 3. Check if a Number is Positive or Negative
# **Task**: Determine if the input number is positive, negative, or zero.
# **Demo Input**: `-3`
# **Demo Output**: `The number is Negative`

# %%
num = float(input("Enter a number: "))

if num > 0:
    print("The number is Positive")
elif num < 0:
    print("The number is Negative")
else:
    print("The number is Zero")
# Out:
# The number is Negative

# %% [markdown]
# ### 4. Calculate the Sum of Digits
# **Task**: Given a number, find the sum of its digits.
# **Demo Input**: `123`
# **Demo Output**: `6`
# (Explanation: `1+2+3=6`)

# %%
num = int(input("Enter a number: "))
sum_of_digits = 0

while num > 0:
    sum_of_digits += num % 10
    num = num // 10

print("Sum of digits is:", sum_of_digits)
# Out:
# Sum of digits is: 6

# %% [markdown]
# ### 5. Find Factorial of a Number
# **Task**: Calculate the factorial of a given number.
# **Demo Input**: `4`
# **Demo Output**: `24`
# (Explanation: `4! = 4*3*2*1 = 24`)

# %%
num = int(input("Enter a number: "))
factorial = 1

for i in range(1, num + 1):
    factorial *= i

print("Factorial is:", factorial)
# Out:
# Factorial is: 24

# %% [markdown]
# ### 6. Count Occurrences of a Digit
# **Task**: Count how many times a specific digit appears max in a number.
# **Demo Input**:  1233321 <br>
# **Demo Output**: `3`  <br>
# (Explanation: `3` appears 3 times in `1233321`)

# %%
num = input("Enter a number: ")
max_count = 0

for digit in set(num):
    count = num.count(digit)
    if count > max_count:
        max_count = count

print("Maximum occurrences of a digit is:", max_count)
# Out:
# Maximum occurrences of a digit is: 3

# %% [markdown]
# ### 7. Find the GCD of Two Numbers
# **Task**: Find the greatest common divisor (GCD) of two numbers.
# **Demo Input**: 8 and 12 <br>
# **Demo Output**: `4`

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

while b != 0:
    a, b = b, a % b

print("GCD is:", a)
# Out:
# GCD is: 4

# %% [markdown]
# ### 8. Reverse a String
# **Task**: Reverse the given string.
# **Demo Input**: `"aiquest"`
# **Demo Output**: `"tseuqia"`

# %%
string = input("Enter a string: ")
reversed_string = string[::-1]
print("Reversed string is:", reversed_string)
# Out:
# Reversed string is: tseuqia

# %% [markdown]
# ### 9. Check Armstrong Number
# **Task**: Check if a number is an Armstrong number (the sum of its digits raised to the power of the number of digits equals the number).
# **Demo Input**: `153`
# **Demo Output**: `153 is an Armstrong Number`
# (Explanation: \(1^3 + 5^3 + 3^3 = 153\))

# %%
num = int(input("Enter a number: "))
num_str = str(num)
num_digits = len(num_str)
sum_of_powers = sum(int(digit) ** num_digits for digit in num_str)

if sum_of_powers == num:
    print(f"{num} is an Armstrong Number")
else:
    print(f"{num} is not an Armstrong Number")
# Out:
# 153 is an Armstrong Number

# %% [markdown]
# ### 10. Generate a Pattern
# **Task**: Print a pyramid pattern with `n` rows.
# **Demo input:** 4 <br>
# **Output:** You will see the pyramid pattern with 4 rows

# %%
n = int(input("Enter number of rows: "))

for i in range(1, n + 1):
    print(" " * (n - i) + "*" * (2 * i - 1))
# Out:
#    *
#   ***
#  *****
# *******

# %% [markdown]
# # Good Luck!
